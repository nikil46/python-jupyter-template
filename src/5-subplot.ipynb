# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Line Plot
x_line = np.arange(0, 11, 1)
y_line = x_line ** 2
axes[0, 0].plot(x_line, y_line, marker='o', linestyle='-', color='b')
axes[0, 0].set_title('Line Plot')

# Bar Plot
axes[0, 1].bar(categories, values, color=colors)
axes[0, 1].set_title('Bar Plot')

# Scatter Plot
axes[1, 0].scatter(x_scatter, y_scatter, color='b')
axes[1, 0].set_title('Scatter Plot')
for i in range(len(x_scatter)):
    axes[1, 0].annotate(f'({x_scatter[i]}, {y_scatter[i]})', (x_scatter[i], y_scatter[i]), textcoords="offset points", xytext=(5,5), ha='center')

    # Pie Chart
    axes[1, 1].pie(sizes, labels=labels, autopct='%1.1f%%', colors=['blue', 'orange', 'green', 'red'])
    axes[1, 1].set_title('Pie Chart')

    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      10 axes[0, 0].set_title('Line Plot')
#      12 # Bar Plot
# ---> 13 axes[0, 1].bar(categories, values, color=colors)
#      14 axes[0, 1].set_title('Bar Plot')
#      16 # Scatter Plot
#
# NameError: name 'categories' is not defined
